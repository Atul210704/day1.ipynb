# %% [markdown]
# <a href="https://colab.research.google.com/github/Atul210704/day1.ipynb/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("atul")
# Out:
# atul
